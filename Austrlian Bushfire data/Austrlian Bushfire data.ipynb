# %%
import pandas as pd
import numpy as np
import seaborn as sns

##Visualization Libraries
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

# %%
file = "C:\\Users\\jun93\\Desktop\\Spring 2020\\CS 301\\Austrlian Bushfire data"

# %%
df = pd.read_csv(file+"\\BushFire.csv")
df.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2019-10-11  6564.299805  6614.600098  6564.299805  6606.799805
# 1  2019-10-14  6622.500000  6676.200195  6622.500000  6642.600098
# 2  2019-10-15  6637.000000  6657.399902  6621.899902  6652.000000
# 3  2019-10-16  6660.000000  6737.799805  6659.700195  6736.500000
# 4  2019-10-17  6730.500000  6737.399902  6681.399902  6684.700195
#
#      Adj Close  Volume
# 0  6606.799805  526900
# 1  6642.600098  489200
# 2  6652.000000  504800
# 3  6736.500000  626500
# 4  6684.700195  871200

# %%
#data_Stocks = file +'\\^AXJO (1).csv'
#dfStocks = pd.read_csv(data_Stocks)
#dfStocks.head(10)

# %%
df.groupby('Date')['Close'].describe().head()
# Out:
#             count         mean  std          min          25%          50%  \
# Date
# 2019-10-11    1.0  6606.799805  NaN  6606.799805  6606.799805  6606.799805
# 2019-10-14    1.0  6642.600098  NaN  6642.600098  6642.600098  6642.600098
# 2019-10-15    1.0  6652.000000  NaN  6652.000000  6652.000000  6652.000000
# 2019-10-16    1.0  6736.500000  NaN  6736.500000  6736.500000  6736.500000
# 2019-10-17    1.0  6684.700195  NaN  6684.700195  6684.700195  6684.700195
#
#                     75%          max
# Date
# 2019-10-11  6606.799805  6606.799805
# 2019-10-14  6642.600098  6642.600098
# 2019-10-15  6652.000000  6652.000000
# 2019-10-16  6736.500000  6736.500000
# 2019-10-17  6684.700195  6684.700195

# %%
df.groupby('Date')['Open'].describe().head()
# Out:
#             count         mean  std          min          25%          50%  \
# Date
# 2019-10-11    1.0  6564.299805  NaN  6564.299805  6564.299805  6564.299805
# 2019-10-14    1.0  6622.500000  NaN  6622.500000  6622.500000  6622.500000
# 2019-10-15    1.0  6637.000000  NaN  6637.000000  6637.000000  6637.000000
# 2019-10-16    1.0  6660.000000  NaN  6660.000000  6660.000000  6660.000000
# 2019-10-17    1.0  6730.500000  NaN  6730.500000  6730.500000  6730.500000
#
#                     75%          max
# Date
# 2019-10-11  6564.299805  6564.299805
# 2019-10-14  6622.500000  6622.500000
# 2019-10-15  6637.000000  6637.000000
# 2019-10-16  6660.000000  6660.000000
# 2019-10-17  6730.500000  6730.500000

# %%
df_fil = df.filter(["High","Low","Volume"])
df_fil.head()
# Out:
#           High          Low  Volume
# 0  6614.600098  6564.299805  526900
# 1  6676.200195  6622.500000  489200
# 2  6657.399902  6621.899902  504800
# 3  6737.799805  6659.700195  626500
# 4  6737.399902  6681.399902  871200

# %%
dfStock = df.drop('High',1).drop('Low',1)
dfStock['Date'] = pd.to_datetime(dfStock['Date'])
dfStock
# Out:
#          Date         Open        Close    Adj Close  Volume
# 0  2019-10-11  6564.299805  6606.799805  6606.799805  526900
# 1  2019-10-14  6622.500000  6642.600098  6642.600098  489200
# 2  2019-10-15  6637.000000  6652.000000  6652.000000  504800
# 3  2019-10-16  6660.000000  6736.500000  6736.500000  626500
# 4  2019-10-17  6730.500000  6684.700195  6684.700195  871200
# ..        ...          ...          ...          ...     ...
# 67 2020-01-17  7041.799805  7064.100098  7064.100098  500300
# 68 2020-01-20  7064.100098  7079.500000  7079.500000  423400
# 69 2020-01-21  7079.500000  7066.299805  7066.299805  480900
# 70 2020-01-22  7066.299805  7132.700195  7132.700195  602000
# 71 2020-01-23  7132.700195  7088.000000  7088.000000  539700
#
# [72 rows x 5 columns]

# %%
plt.plot(df['Date'], df['Close'], label='ASX 200 Stock', color='green')
plt.gcf().autofmt_xdate()
plt.gcf().set_size_inches(18,8)
plt.ylabel('Stock Close Values($)')
plt.xlabel('Date')
plt.title('Australian Stock Exchange(ASX 200) Close Values from October 2019 - January 2020')
plt.tight_layout()
plt.legend()
plt.show()

# %%
ax = sns.barplot(x='Date',y='Volume',data=df)
for ind, label in enumerate(ax.get_xticklabels()):
    if ind % 10 == 0:  # every 10th label is kept
        label.set_visible(True)
    else:
        label.set_visible(False)
plt.gcf().set_size_inches(15,5)
plt.xlabel("Date")
plt.ylabel('FRP (fire radiation power)')
plt.title("time line of bushfire in Australia")
plt.show()

# %%
#fire_nrt_m6 = pd.read_csv(file+"\\fire_archive_M6_101673.csv")
#fire_archive_m6 = pd.read_csv(file+"\\fire_archive_M6_101673.csv")
fire_nrt_v1 = pd.read_csv(file+"\\fire_nrt_V1_101674.csv")
fire_archive_v1 = pd.read_csv(file+"\\fire_archive_V1_101674.csv")

data1 = fire_nrt_v1
data2 = fire_archive_v1

type(fire_nrt_v1)
fire_nrt_v1.head()
fire_archive_v1.head()
# Out:
#    latitude  longitude  bright_ti4  scan  track    acq_date  acq_time  \
# 0 -37.48861  149.63156       341.1  0.41   0.60  2019-09-01       304
# 1 -34.46110  150.88142       328.5  0.33   0.55  2019-09-01       305
# 2 -33.94823  151.21292       341.1  0.62   0.54  2019-09-01       305
# 3 -34.45618  150.87723       328.5  0.33   0.55  2019-09-01       305
# 4 -31.60223  150.15147       367.0  0.34   0.56  2019-09-01       306
#
#   satellite instrument confidence  version  bright_ti5   frp  type
# 0         N      VIIRS          n        1       293.7   4.4     0
# 1         N      VIIRS          l        1       298.5   2.1     2
# 2         N      VIIRS          n        1       295.3   6.4     0
# 3         N      VIIRS          n        1       298.1   2.1     2
# 4         N      VIIRS          h        1       302.4  19.3     0

# %%
df_merge = pd.concat([fire_archive_v1, fire_nrt_v1],sort=True)
data = df_merge
data.head()
# Out:
#      acq_date  acq_time  bright_ti4  bright_ti5 confidence daynight   frp  \
# 0  2019-09-01       304       341.1       293.7          n      NaN   4.4
# 1  2019-09-01       305       328.5       298.5          l      NaN   2.1
# 2  2019-09-01       305       341.1       295.3          n      NaN   6.4
# 3  2019-09-01       305       328.5       298.1          n      NaN   2.1
# 4  2019-09-01       306       367.0       302.4          h      NaN  19.3
#
#   instrument  latitude  longitude satellite  scan  track  type version
# 0      VIIRS -37.48861  149.63156         N  0.41   0.60   0.0       1
# 1      VIIRS -34.46110  150.88142         N  0.33   0.55   2.0       1
# 2      VIIRS -33.94823  151.21292         N  0.62   0.54   0.0       1
# 3      VIIRS -34.45618  150.87723         N  0.33   0.55   2.0       1
# 4      VIIRS -31.60223  150.15147         N  0.34   0.56   0.0       1

# %%
df_filter = data.filter(["latitude","longitude","acq_date","frp"])
df_filter.head()
# Out:
#    latitude  longitude    acq_date   frp
# 0 -37.48861  149.63156  2019-09-01   4.4
# 1 -34.46110  150.88142  2019-09-01   2.1
# 2 -33.94823  151.21292  2019-09-01   6.4
# 3 -34.45618  150.87723  2019-09-01   2.1
# 4 -31.60223  150.15147  2019-09-01  19.3

# %%
df = df_filter[df_filter['acq_date']>='2019-11-01']
df.head()
# Out:
#         latitude  longitude    acq_date  frp
# 141333 -30.90384  148.78645  2019-11-01  9.4
# 141334 -29.93590  149.08118  2019-11-01  8.1
# 141335 -30.90112  148.78107  2019-11-01  5.2
# 141336 -31.21953  147.99135  2019-11-01  4.8
# 141337 -30.90465  148.78191  2019-11-01  5.2

# %%
data_topaffected = df.sort_values(by='frp',ascending=False)
data_topaffected.head(10)
# Out:
#         latitude  longitude    acq_date      frp
# 942985 -36.97858  146.71938  2020-01-08  10717.2
# 943024 -35.89541  136.54585  2020-01-08   5611.8
# 943059 -35.79238  136.59879  2020-01-08   4948.8
# 894088 -36.77020  148.00307  2020-01-04   4156.6
# 943016 -35.89769  136.55919  2020-01-08   3736.3
# 943036 -35.88688  137.07683  2020-01-08   3501.9
# 943035 -35.88832  137.08549  2020-01-08   3497.9
# 943017 -35.89693  136.55476  2020-01-08   3372.0
# 943020 -35.89618  136.55032  2020-01-08   3372.0
# 943076 -35.80969  136.60056  2020-01-08   3282.1

# %%
dfdate = df[['acq_date','frp']].set_index('acq_date')
dfdate_highest = dfdate.groupby('acq_date').sum().sort_values(by='frp',ascending=False)
dfdate_highest.head(10)
# Out:
#                   frp
# acq_date
# 2020-01-04  1653384.1
# 2019-12-30   883598.6
# 2019-11-08   542117.9
# 2019-12-29   529525.8
# 2020-01-02   520606.0
# 2019-12-21   344399.0
# 2019-12-19   333303.5
# 2020-01-03   317426.7
# 2020-01-01   312001.9
# 2019-12-31   285330.3

# %%
ax = sns.barplot(x='acq_date',y='frp',data=df)
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
#plt.gcf().autofmt_xdate()
for ind, label in enumerate(ax.get_xticklabels()):
    if ind % 10 == 0:  # every 10th label is kept
        label.set_visible(True)
    else:
        label.set_visible(False)
plt.gcf().set_size_inches(15,5)
plt.xlabel("Date")
plt.ylabel('FRP (fire radiation power)')
plt.title("time line of bushfire in Australia")
plt.show()

# %%
fig, ax_cost = plt.subplots()

fig.set_figwidth(22)
fig.set_figheight(10)

ax_cost.set_xlabel('Date')

#ax_cost.tick_params(axis = 'x', bottom=False, labelbottom=False)

ax_cost.set_ylabel('Stock Close Values($)', color='r', size='x-large')

ax_cost.plot(dfStock['Date'], dfStock['Close'], color= 'r')

ax_tempF = ax_cost.twinx()

ax_tempF.set_ylabel('FRP (fire radiation power)', color='b', size='x-large')
#ax_tempF.tick_params(axis = 'x', bottom=False, labelbottom=False)
df_merge = pd.concat([fire_archive_v1, fire_nrt_v1],sort=True)
ax_tempF.plot(dfStock['Date'],dfStock['Volume'], color='b')

plt.title("Stock value vs. FRP power")
plt.gcf().autofmt_xdate()
